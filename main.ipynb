# %%
from pydub import AudioSegment
import whisper
model = whisper.load_model("medium")
result = model.transcribe("/Users/chunchun/pyClassKeeping/嵌入式系統_L1.m4a",language='zh')
print(result["text"])
# Out:
# /Users/chunchun/.local/share/virtualenvs/pyClassKeeping-ytPZiK5j/lib/python3.10/site-packages/whisper/timing.py:58: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def backtrace(trace: np.ndarray):
# /Users/chunchun/.local/share/virtualenvs/pyClassKeeping-ytPZiK5j/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 它本身可以被大致分類成兩種分別是類比訊號反射器以及數位訊號反射器類比訊號反射器它主要是針對測量到的數值跟參數去產生一對一的結果所以它產生的資訊會長得像左下角一樣你們是左下角嗎?你們是右下角嗎?右下角平常是不好意思重軸是電壓橫軸是時間隨著時間的過去類比探測器會產生一系列連續的結果將資訊傳送到前路路系統內除了類比訊號反射器之外還有另外一種叫做數位反射器的反射器它主要產生的結果是一系列的discrete output它主要反應的是電地訊號的存在與否它通常可以是半壓力的形式例如像0或1它所產生的資訊會長得像左下角這張圖這張圖就是一張典型的包含0跟1的數位感測器的output那感測器具體上有哪一些呢?其實有非常多種我們這邊可以跟你們介紹幾種比較常見的感測器很多你們可能都看過第一種是溫度的感測器它通常用來感測一個房間或空氣中的溫度說到溫度就不提到濕度感測器濕度感測器可以用來測量空氣中水分的含量還有一種是很常見的叫做光感測器它可以偵測光的強度它比較特別的是它通常不需要電力去供應它因為它的感測原理是將收到的光能直接轉換為電力來輸出還有一些比較不常見到的感測器像是力感測器這種感測器可以感測施加在物體上的力量它可以是很簡單的按鍵決定按下或不按下它也可以是很多程度的壓力感測然後是流量感測器它可以檢測流體的流速跟分量像是流動的空氣或液體等等都屬於它的監控範疇最後是顏色感測器它可以感知物體的顏色並且將喜好複成不同格式的顏色訊號像是RPG或是更進階的ACX等等當然除此之外還有很多種不同的感測器這邊就不一一列舉同學有興趣也可以上網找找看講完感測器我們接著要了解一下什麼是執行器執行器它是一種把各種能源轉換成機械動能的自動方式它可以幫助嵌入式系統做出實際的控制驅使物體進行各種預想操作最典型的像是馬達或是機械手臂很多種不同的形式可以看到我這邊列了八種很多你們可能沒有看過的但是就是了解它是一個自動器嵌入式系統主要有以下幾個特色第一它通常是單一應用或是功能特化這樣的特殊設計可以使得嵌入式系統在特殊用途上能比一般的傳統PC執行的更快更有效率一個嵌入式系統它通常也以回電腦的核心並且周邊的零件構成把一整個系統例如說我們可以把一整個系統整合在一片晶片上這種概念通常也是做CNR去例如從8051的單晶片到ARM處理器等等再來它通常會有更嚴格的限制跟穩定度的要求想想一個全自動化的製作工廠它如果今天一個環節出錯了會怎麼樣假設你的工廠要再組裝基木環境比如說其中的地方Pin-Tor的地方漏掉了那你後面的基木全部都組不上就變成疊效應這是有可能的所以這種嚴謹的要求它的主因是因為嵌入式系統一般需要的小尺寸低能耗低成本以及有效執行的面向等等的考量最後一個是嵌入系統它必須要能夠及時的處理跟覆核例如在機器控制上稍微延誤的話又可能導致不可防備的錯誤以上這幾點都是嵌入系統它的特色總結來說如果用一句話來定義的話什麼是嵌入系統嵌入系統它的定義就是一種小規模的軟硬體的整合當一個微電腦系統在軟硬體緊密結合的情況下針對某種特定的應用所設計的系統這種系統就稱作嵌入式系統看到畫線就知道等會考各位要做那如果是上課當天都可以做筆記上課當天放喔上課前可能五分鐘十分鐘因為我們可以打下來我可以打下來聽你講一遍要做筆記喔那我上課前十到十五分鐘會不會太短啊如果要放的話可能提到多久比較好看老師好好啊感謝同學提出那我就上課前十分多放下去可以設定時間真的嗎我不知道有這個設定想讓MUTO把記憶準備好那我再去試試看那下一集就開始那會提早十分鐘嗎這樣大家可以看一下因為確實啊我看到很多同學做筆記這樣看可能會有點不對OK那下一堂課開始再就是前十分鐘我會把頭銀給放上去這樣幫MUTO幫你謝謝好那接下來我們來比較一下一般的電腦系統跟嵌入式系統的不同那首先我們所認知的電腦系統它一般是屬於看得見的電腦它能泛用在任何的目標它可以按照結構一段速度跟規模去做分類而嵌入式系統呢不一樣它通常是一種看不見的電腦那它的設計目的通常就是為了實現特定的目標它的形式都一樣沒有特定的結構所以通常呢我們可以用應用來區分它在組成元件方面呢兩者也有點不同那電腦系統它通常是被泛用型的處理器比如說大家所知的Intel、AMD這些那標準的會流排、PCIe之類的外部的周邊設備比如說滑鼠、鍵盤那其軟體跟硬體相對獨立而嵌入式系統呢則通常是特殊應用導向的微處理器整合於處理器內的會流排與周邊元件它的軟體跟硬體呢是緊密結合電腦系統的開發平台與應用呢它的執行都是在泛用型的電腦上面而嵌入式系統呢則是採用Cross-frameform development那通常它的開發平台呢會是在host system泛用型的電腦上面但是它的應用執行平台則是在topic system嵌入式系統上這個Cross-frameform development呢還沒有講到或者先給大家一個概念那到後面我們課程會講到軟體的部分的時候我們會詳細解釋那在電腦系統上應用程式它通常可以被recovered但是在嵌入式系統上應用程式呢它通常不能被recovered那這邊指的通常就是在電腦系統上那介紹完什麼是嵌入式系統之後呢我們的日常生活中有哪些可以看到嵌入式系統的其實呢到處都是喔圖片中這些紅點呢都是嵌入式的系統那有沒有哪些是你們從來沒有講過的是嵌入式系統呢那在嵌入式系統上我們有哪些可以看到嵌入式系統呢其實呢到處都是喔圖片中這些紅點呢都是嵌入式的系統那有沒有哪些是你們從來沒有講過的是嵌入式系統呢人為什麼是比較特別的比較特別的電話它的軟體成分很低這樣也算嗎它只要是為了特定應用去實現它那我們就把它自行為什麼人的頭也是嵌入式系統人的頭人的頭坐在那個點它可能是機器它可能是腦部有問題或被植入一個什麼或是它耳朵可能有帶出機器對因為一個比較可惜好OK 大家大概看一下覺得有趣那接下來我們會介紹一些常見或不常見的嵌入式的系統的應用實例那這裡可以當作同學們期末專題題目的發想題目然後講到期末專題題目你們如果分好組或想要題目就可以寄進去目前還沒有人寄你這樣先想好題目對阿對阿先想好題目然後把你的組員跟學號一起附上這樣我都登記掉題目不能重複所以誰先想到譬如說兩組都講到智慧型手機智慧型手機第一組就先想給對那我的email可以在電子系家族的機上找到我好所以我接下來會講一些嵌入式系統的實例那也代表同學的發想那你要做我講的這些實例當然也可以但是因為我講過了你們要做的話就要更加深入對那老師會建議大家找今天老師講的以外的例子在創意跟發想上會有比較好的成果那首先最常見的智慧型手機智慧型手機它的演變非常的快速那同學們知道最原始的手機是長什麼樣的嗎不知道我其實也不知道但是左上角這個手機有人知道什麼嗎是右上角抱歉你們是投影出來的右上角這個手機所以你們跟我翻箱相反你們是左上嗎OKOK左上角這個手機有人知道什麼嗎黑金剛好有人跟我連帶這樣現在很多同學可能沒有實際見過它就連我其實也沒有實際見過它那我知道說大家好像都叫它黑金剛那它聽說它主要的功能不是用來打電話是用來打人其實我是開玩笑的開玩笑的那左下角這一隻應該就有不少人知道那個大名鼎鼎的這個T3310那它最厲害的不是它裡面的傳輸它最厲害的是刀槍不入大家可以有興趣Google一下看看你打的那種T3310的傳輸就知道它有什麼事情這個有題外話我們正要講的智慧型手機就是右手邊這兩個那隨著科技的行業手機天天開始有智慧那變成右手邊那個智慧型手機那這個也通常也大概是大家手上現在幾乎人手一次的時尚物那最近還推出了可以折疊的手機我覺得蠻新奇的那這些科技的進步呢就讓人們使用上來帶來什麼方便的東西折疊式的手機手在實在的前端應該還沒有原來有點貴那既然智慧型手機那麼神通廣大它可以打電話上網然後可以玩遊戲那大家要把手機拆開過看看裡面有什麼怎麼樣的這邊有一張圖可以就足智慧型手機大致上是有哪些原件所作成那包含手機運作需要的電池存資料它所需要的Fresh memory然後導航所需的GPS玩遊戲需要的重力感測器跟GPU 感測器智慧型手機就是一個嵌入系統的實例常見那我再來舉一個另外一個實例它是智慧型手錶那人類最一開始發明的手錶當什麼樣子不可考最左邊的這個呢是懷錶那也是我親眼見過最古老的錶那其實現在你們去一些古典風的國家還是可以看得到它存在那它的用途可能已經不是當作手錶這麼簡單了它可能是有時候是一種懷念的功能那現代版的手機大概都長得像右邊這兩面一個小小的手錶它內餡有許多的功能它可以幫你監控你的運動習慣心跳、甚至血壓那監控血壓呢目前還沒有很準確那老師很想買一支券幫你監控的手錶但目前血壓的部分好像還沒有很完善如果同學知道很完善監控血壓的手錶可以推薦一下老師那更神奇的是現在的智慧型手錶甚至還可以通話那你可以像動畫裡面科南一樣用手錶想畫但是射手錶應該是不行因為太危險了剛剛講到通話的部分那因為台灣目前好像還有一些通訊限定的問題所以就我了解目前智慧型手錶還沒有辦法完全做到取代手機通話的功能它還是需要透過手錶來當作一個接入然後它才完成這個接入電話的功能有點可惜不過我們可以期待不久的將來手錶還能完全的取代手機通話的功能這是一張智慧型手錶才開後的樣子那比起手機大家可以看到它的各項元件更小更細細那它也更focus在特殊功能的實現所以智慧型手錶它也是一個典型的有前後系統的實例電視呢也從以前左邊的傳統電視進化到現在的智慧電視雖然說你看起來電視好像變薄了但實際上它裡面的運作呢其實是更複雜這是一隻智慧電視的系統可以看到現在的智慧電視能夠接受的各式各樣的訊號也的輸入那並且可以透過裡面複雜的系統來轉換將這個視訊輸出到一級面板上讓大家觀看那除此之外呢智慧車載系統也是一個前路式系統的零用實例現在車子裡面導航跟平板系統它已經是標配還有很多的新的監控系統慢慢的被加入到車載系統中那比如說智慧輔助系統輔助駕駛系統特斯拉還有車輛軌跡系統這些是已經被加進去 ...
